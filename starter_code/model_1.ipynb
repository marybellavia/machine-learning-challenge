# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Collecting sklearn
#   Downloading https://files.pythonhosted.org/packages/1e/7a/dbb3be0ce9bd5c8b7e3d87328e79063f8b263b2b1bfa4774cb1147bfcd3f/sklearn-0.0.tar.gz
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\mary\anaconda3\lib\site-packages (from sklearn) (0.21.3)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\mary\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.13.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in c:\users\mary\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.16.5)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in c:\users\mary\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.3.1)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1321 sha256=7bba3baa68d13a3bf9ab0dcf83753f7751de30e60dc03ab6bac5738f0fffd445
#   Stored in directory: C:\Users\Mary\AppData\Local\pip\Cache\wheels\76\03\bb\589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\mary\anaconda3\lib\site-packages (0.13.2)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
col_list = list(df.columns)[1:]
selected_features = df[col_list]
selected_features
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0        2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1        1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2        2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3        3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4        1.050000e-05    -1.050000e-05   172.979370          0.001900
# ...               ...              ...          ...               ...
# 6986     1.846000e-04    -1.846000e-04   132.016100          0.015700
# 6987     1.160000e-07    -1.160000e-07   131.705093          0.000170
# 6988     1.780000e-05    -1.780000e-05   133.001270          0.007690
# 6989     2.430000e-06    -2.430000e-06   132.181750          0.002850
# 6990     6.360000e-05    -6.360000e-05   135.993300          0.010800
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0            -0.003520  ...             -81      4.467           0.064
# 1            -0.000581  ...            -176      4.544           0.044
# 2            -0.000115  ...            -174      4.564           0.053
# 3            -0.001130  ...            -211      4.438           0.070
# 4            -0.001900  ...            -232      4.486           0.054
# ...                ...  ...             ...        ...             ...
# 6986         -0.015700  ...            -152      4.296           0.231
# 6987         -0.000170  ...            -166      4.529           0.035
# 6988         -0.007690  ...            -220      4.444           0.056
# 6989         -0.002850  ...            -236      4.447           0.056
# 6990         -0.010800  ...            -225      4.385           0.054
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0             -0.096     0.927          0.105         -0.061  291.93423
# 1             -0.176     0.868          0.233         -0.078  297.00482
# 2             -0.168     0.791          0.201         -0.067  285.53461
# 3             -0.210     1.046          0.334         -0.133  288.75488
# 4             -0.229     0.972          0.315         -0.105  296.28613
# ...              ...       ...            ...            ...        ...
# 6986          -0.189     1.088          0.313         -0.228  298.74921
# 6987          -0.196     0.903          0.237         -0.079  297.18875
# 6988          -0.224     1.031          0.341         -0.114  286.50937
# 6989          -0.224     1.041          0.341         -0.114  294.16489
# 6990          -0.216     1.193          0.410         -0.137  297.00977
#
#             dec  koi_kepmag
# 0     48.141651      15.347
# 1     48.134129      15.436
# 2     48.285210      15.597
# 3     48.226200      15.509
# 4     48.224670      15.714
# ...         ...         ...
# 6986  46.973351      14.478
# 6987  47.093819      14.082
# 6988  47.163219      14.757
# 6989  47.176281      15.385
# 6990  47.121021      14.826
#
# [6991 rows x 40 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# creating X and y from dataframe
X = selected_features
y = df['koi_disposition']

# Use train_test_split to create training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3563              0              0              0              0   10.548413
# 4099              0              0              0              0   24.754385
# 5460              0              0              0              0    1.057336
# 1091              0              0              0              0  201.118319
# 5999              0              0              0              0   91.649983
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 3563     5.470000e-05    -5.470000e-05   139.064020          0.004110
# 4099     1.365000e-04    -1.365000e-04   140.207320          0.004460
# 5460     1.230000e-07    -1.230000e-07   131.792007          0.000096
# 1091     1.461000e-03    -1.461000e-03   187.569860          0.005290
# 5999     3.181000e-03    -3.181000e-03   175.715600          0.028600
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 3563         -0.004110  ...            -133      4.387           0.066
# 4099         -0.004460  ...            -144      4.519           0.078
# 5460         -0.000096  ...            -140      4.594           0.054
# 1091         -0.005290  ...            -112      4.447           0.072
# 5999         -0.028600  ...            -233      4.145           0.164
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 3563          -0.123     1.092          0.181         -0.097  298.09543
# 4099          -0.052     0.804          0.056         -0.076  295.73535
# 5460          -0.027     0.683          0.054         -0.060  292.18417
# 1091          -0.108     0.954          0.135         -0.083  283.11377
# 5999          -0.164     1.608          0.905         -0.383  294.93198
#
#             dec  koi_kepmag
# 3563  44.737061      13.204
# 4099  42.576248      15.514
# 5460  49.310040      15.414
# 1091  48.131390      13.328
# 5999  39.812420      12.964
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train, X_test)
X_test_scaled = scaler.fit_transform(X_test, X_test)

# %%
# from sklearn.preprocessing import MinMaxScaler
# X_scaler = MinMaxScaler().fit(X_train)

# X_train_scaled = X_scaler.transform(X_train)
# X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.ensemble import RandomForestClassifier
model1 = RandomForestClassifier(n_estimators=200)
model1 = model1.fit(X_train, y_train)
model1.score(X_test, y_test)
# Out:
# 0.9050343249427918

# %%
print(f"Training Data Score: {model1.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model1.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.7137135227922945
# Testing Data Score: 0.7259725400457666

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators': [50, 150, 250],
              'max_features': ['sqrt', 0.25, 0.5, 0.75, 1.0],
              'min_samples_split': [2, 4, 6]}
grid = GridSearchCV(model1, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train, y_train)
# Out:
# C:\Users\Mary\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=50 .........
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=50, score=0.888, total=   1.1s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=50 .........
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=50, score=0.890, total=   1.1s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=50 .........
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.1s remaining:    0.0s
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=50, score=0.880, total=   1.1s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=150 ........
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=150, score=0.886, total=   3.2s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=150 ........
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=150, score=0.893, total=   3.1s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=150 ........
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=150, score=0.883, total=   3.2s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=250 ........
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=250, score=0.891, total=   5.8s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=250 ........
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=250, score=0.895, total=   5.3s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=250 ........
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=250, score=0.882, total=   5.4s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=50 .........
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=50, score=0.882, total=   1.0s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=50 .........
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=50, score=0.892, total=   1.1s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=50 .........
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=50, score=0.870, total=   1.0s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=150 ........
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=150, score=0.888, total=   3.2s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=150 ........
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=150, score=0.898, total=   3.2s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=150 ........
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=150, score=0.882, total=   3.1s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=250 ........
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=250, score=0.886, total=   5.6s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=250 ........
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=250, score=0.898, total=   5.0s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=250 ........
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=250, score=0.882, total=   4.9s
# [CV] max_features=sqrt, min_samples_split=6, n_estimators=50 .........
# [CV]  max_features=sqrt, min_samples_split=6, n_estimators=50, score=0.879, total=   1.1s
# [CV] max_features=sqrt, min_samples_split=6, n_estimators=50 .........
# [CV]  max_features=sqrt, min_samples_split=6, n_estimators=50, score=0.893, total=   1.1s
# [CV] max_features=sqrt, min_samples_split=6, n_estimators=50 .........
# [CV]  max_features=sqrt, min_samples_split=6, n_estimators=50, score=0.879, total=   1.0s
# [CV] max_features=sqrt, min_samples_split=6, n_estimators=150 ........
# [CV]  max_features=sqrt, min_samples_split=6, n_estimators=150, score=0.884, total=   3.1s
# [CV] max_features=sqrt, min_samples_split=6, n_estimators=150 ........
# [CV]  max_features=sqrt, min_samples_split=6, n_estimators=150, score=0.894, total=   3.3s
# [CV] max_features=sqrt, min_samples_split=6, n_estimators=150 ........
# [CV]  max_features=sqrt, min_samples_split=6, n_estimators=150, score=0.887, total=   3.3s
# [CV] max_features=sqrt, min_samples_split=6, n_estimators=250 ........
# [CV]  max_features=sqrt, min_samples_split=6, n_estimators=250, score=0.889, total=   5.4s
# [CV] max_features=sqrt, min_samples_split=6, n_estimators=250 ........
# [CV]  max_features=sqrt, min_samples_split=6, n_estimators=250, score=0.896, total=   5.1s
# [CV] max_features=sqrt, min_samples_split=6, n_estimators=250 ........
# [CV]  max_features=sqrt, min_samples_split=6, n_estimators=250, score=0.881, total=   5.3s
# [CV] max_features=0.25, min_samples_split=2, n_estimators=50 .........
# [CV]  max_features=0.25, min_samples_split=2, n_estimators=50, score=0.891, total=   1.6s
# [CV] max_features=0.25, min_samples_split=2, n_estimators=50 .........
# [CV]  max_features=0.25, min_samples_split=2, n_estimators=50, score=0.896, total=   1.7s
# [CV] max_features=0.25, min_samples_split=2, n_estimators=50 .........
# [CV]  max_features=0.25, min_samples_split=2, n_estimators=50, score=0.886, total=   1.6s
# [CV] max_features=0.25, min_samples_split=2, n_estimators=150 ........
# [CV]  max_features=0.25, min_samples_split=2, n_estimators=150, score=0.895, total=   4.6s
# [CV] max_features=0.25, min_samples_split=2, n_estimators=150 ........
# [CV]  max_features=0.25, min_samples_split=2, n_estimators=150, score=0.902, total=   4.9s
# [CV] max_features=0.25, min_samples_split=2, n_estimators=150 ........
# [CV]  max_features=0.25, min_samples_split=2, n_estimators=150, score=0.881, total=   5.1s
# [CV] max_features=0.25, min_samples_split=2, n_estimators=250 ........
# [CV]  max_features=0.25, min_samples_split=2, n_estimators=250, score=0.895, total=   8.1s
# [CV] max_features=0.25, min_samples_split=2, n_estimators=250 ........
# [CV]  max_features=0.25, min_samples_split=2, n_estimators=250, score=0.902, total=   8.1s
# [CV] max_features=0.25, min_samples_split=2, n_estimators=250 ........
# [CV]  max_features=0.25, min_samples_split=2, n_estimators=250, score=0.890, total=   8.3s
# [CV] max_features=0.25, min_samples_split=4, n_estimators=50 .........
# [CV]  max_features=0.25, min_samples_split=4, n_estimators=50, score=0.892, total=   1.7s
# [CV] max_features=0.25, min_samples_split=4, n_estimators=50 .........
# [CV]  max_features=0.25, min_samples_split=4, n_estimators=50, score=0.896, total=   1.7s
# [CV] max_features=0.25, min_samples_split=4, n_estimators=50 .........
# [CV]  max_features=0.25, min_samples_split=4, n_estimators=50, score=0.888, total=   1.7s
# [CV] max_features=0.25, min_samples_split=4, n_estimators=150 ........
# [CV]  max_features=0.25, min_samples_split=4, n_estimators=150, score=0.894, total=   4.8s
# [CV] max_features=0.25, min_samples_split=4, n_estimators=150 ........
# [CV]  max_features=0.25, min_samples_split=4, n_estimators=150, score=0.904, total=   4.9s
# [CV] max_features=0.25, min_samples_split=4, n_estimators=150 ........
# [CV]  max_features=0.25, min_samples_split=4, n_estimators=150, score=0.890, total=   4.9s
# [CV] max_features=0.25, min_samples_split=4, n_estimators=250 ........
# [CV]  max_features=0.25, min_samples_split=4, n_estimators=250, score=0.892, total=   8.2s
# [CV] max_features=0.25, min_samples_split=4, n_estimators=250 ........
# [CV]  max_features=0.25, min_samples_split=4, n_estimators=250, score=0.903, total=   8.4s
# [CV] max_features=0.25, min_samples_split=4, n_estimators=250 ........
# [CV]  max_features=0.25, min_samples_split=4, n_estimators=250, score=0.889, total=   8.4s
# [CV] max_features=0.25, min_samples_split=6, n_estimators=50 .........
# [CV]  max_features=0.25, min_samples_split=6, n_estimators=50, score=0.882, total=   1.6s
# [CV] max_features=0.25, min_samples_split=6, n_estimators=50 .........
# [CV]  max_features=0.25, min_samples_split=6, n_estimators=50, score=0.899, total=   1.6s
# [CV] max_features=0.25, min_samples_split=6, n_estimators=50 .........
# [CV]  max_features=0.25, min_samples_split=6, n_estimators=50, score=0.883, total=   1.7s
# [CV] max_features=0.25, min_samples_split=6, n_estimators=150 ........
# [CV]  max_features=0.25, min_samples_split=6, n_estimators=150, score=0.894, total=   5.1s
# [CV] max_features=0.25, min_samples_split=6, n_estimators=150 ........
# [CV]  max_features=0.25, min_samples_split=6, n_estimators=150, score=0.903, total=   4.9s
# [CV] max_features=0.25, min_samples_split=6, n_estimators=150 ........
# [CV]  max_features=0.25, min_samples_split=6, n_estimators=150, score=0.882, total=   5.0s
# [CV] max_features=0.25, min_samples_split=6, n_estimators=250 ........
# [CV]  max_features=0.25, min_samples_split=6, n_estimators=250, score=0.893, total=   7.8s
# [CV] max_features=0.25, min_samples_split=6, n_estimators=250 ........
# [CV]  max_features=0.25, min_samples_split=6, n_estimators=250, score=0.904, total=   8.2s
# [CV] max_features=0.25, min_samples_split=6, n_estimators=250 ........
# [CV]  max_features=0.25, min_samples_split=6, n_estimators=250, score=0.883, total=   8.1s
# [CV] max_features=0.5, min_samples_split=2, n_estimators=50 ..........
# [CV]  max_features=0.5, min_samples_split=2, n_estimators=50, score=0.890, total=   3.4s
# [CV] max_features=0.5, min_samples_split=2, n_estimators=50 ..........
# [CV]  max_features=0.5, min_samples_split=2, n_estimators=50, score=0.897, total=   3.2s
# [CV] max_features=0.5, min_samples_split=2, n_estimators=50 ..........
# [CV]  max_features=0.5, min_samples_split=2, n_estimators=50, score=0.887, total=   3.0s
# [CV] max_features=0.5, min_samples_split=2, n_estimators=150 .........
# [CV]  max_features=0.5, min_samples_split=2, n_estimators=150, score=0.892, total=   9.3s
# [CV] max_features=0.5, min_samples_split=2, n_estimators=150 .........
# [CV]  max_features=0.5, min_samples_split=2, n_estimators=150, score=0.900, total=  12.1s
# [CV] max_features=0.5, min_samples_split=2, n_estimators=150 .........
# [CV]  max_features=0.5, min_samples_split=2, n_estimators=150, score=0.890, total=  11.0s
# [CV] max_features=0.5, min_samples_split=2, n_estimators=250 .........
# [CV]  max_features=0.5, min_samples_split=2, n_estimators=250, score=0.892, total=  22.1s
# [CV] max_features=0.5, min_samples_split=2, n_estimators=250 .........
# [CV]  max_features=0.5, min_samples_split=2, n_estimators=250, score=0.900, total=  19.2s
# [CV] max_features=0.5, min_samples_split=2, n_estimators=250 .........
# [CV]  max_features=0.5, min_samples_split=2, n_estimators=250, score=0.890, total=  19.6s
# [CV] max_features=0.5, min_samples_split=4, n_estimators=50 ..........
# [CV]  max_features=0.5, min_samples_split=4, n_estimators=50, score=0.895, total=   4.7s
# [CV] max_features=0.5, min_samples_split=4, n_estimators=50 ..........
# [CV]  max_features=0.5, min_samples_split=4, n_estimators=50, score=0.898, total=   3.7s
# [CV] max_features=0.5, min_samples_split=4, n_estimators=50 ..........
# [CV]  max_features=0.5, min_samples_split=4, n_estimators=50, score=0.891, total=   3.5s
# [CV] max_features=0.5, min_samples_split=4, n_estimators=150 .........
# [CV]  max_features=0.5, min_samples_split=4, n_estimators=150, score=0.892, total=  12.2s
# [CV] max_features=0.5, min_samples_split=4, n_estimators=150 .........
# [CV]  max_features=0.5, min_samples_split=4, n_estimators=150, score=0.902, total=   9.5s
# [CV] max_features=0.5, min_samples_split=4, n_estimators=150 .........
# [CV]  max_features=0.5, min_samples_split=4, n_estimators=150, score=0.890, total=  11.8s
# [CV] max_features=0.5, min_samples_split=4, n_estimators=250 .........
# [CV]  max_features=0.5, min_samples_split=4, n_estimators=250, score=0.894, total=  18.1s
# [CV] max_features=0.5, min_samples_split=4, n_estimators=250 .........
# [CV]  max_features=0.5, min_samples_split=4, n_estimators=250, score=0.902, total=  18.7s
# [CV] max_features=0.5, min_samples_split=4, n_estimators=250 .........
# [CV]  max_features=0.5, min_samples_split=4, n_estimators=250, score=0.891, total=  18.2s
# [CV] max_features=0.5, min_samples_split=6, n_estimators=50 ..........
# [CV]  max_features=0.5, min_samples_split=6, n_estimators=50, score=0.891, total=   3.0s
# [CV] max_features=0.5, min_samples_split=6, n_estimators=50 ..........
# [CV]  max_features=0.5, min_samples_split=6, n_estimators=50, score=0.903, total=   2.8s
# [CV] max_features=0.5, min_samples_split=6, n_estimators=50 ..........
# [CV]  max_features=0.5, min_samples_split=6, n_estimators=50, score=0.890, total=   2.8s
# [CV] max_features=0.5, min_samples_split=6, n_estimators=150 .........
# [CV]  max_features=0.5, min_samples_split=6, n_estimators=150, score=0.893, total=  11.8s
# [CV] max_features=0.5, min_samples_split=6, n_estimators=150 .........
# [CV]  max_features=0.5, min_samples_split=6, n_estimators=150, score=0.900, total=   8.8s
# [CV] max_features=0.5, min_samples_split=6, n_estimators=150 .........
# [CV]  max_features=0.5, min_samples_split=6, n_estimators=150, score=0.895, total=   8.9s
# [CV] max_features=0.5, min_samples_split=6, n_estimators=250 .........
# [CV]  max_features=0.5, min_samples_split=6, n_estimators=250, score=0.892, total=  15.1s
# [CV] max_features=0.5, min_samples_split=6, n_estimators=250 .........
# [CV]  max_features=0.5, min_samples_split=6, n_estimators=250, score=0.902, total=  14.8s
# [CV] max_features=0.5, min_samples_split=6, n_estimators=250 .........
# [CV]  max_features=0.5, min_samples_split=6, n_estimators=250, score=0.891, total=  17.5s
# [CV] max_features=0.75, min_samples_split=2, n_estimators=50 .........
# [CV]  max_features=0.75, min_samples_split=2, n_estimators=50, score=0.884, total=   4.5s
# [CV] max_features=0.75, min_samples_split=2, n_estimators=50 .........
# [CV]  max_features=0.75, min_samples_split=2, n_estimators=50, score=0.896, total=   4.6s
# [CV] max_features=0.75, min_samples_split=2, n_estimators=50 .........
# [CV]  max_features=0.75, min_samples_split=2, n_estimators=50, score=0.888, total=   4.7s
# [CV] max_features=0.75, min_samples_split=2, n_estimators=150 ........
# [CV]  max_features=0.75, min_samples_split=2, n_estimators=150, score=0.891, total=  16.5s
# [CV] max_features=0.75, min_samples_split=2, n_estimators=150 ........
# [CV]  max_features=0.75, min_samples_split=2, n_estimators=150, score=0.899, total=  13.6s
# [CV] max_features=0.75, min_samples_split=2, n_estimators=150 ........
# [CV]  max_features=0.75, min_samples_split=2, n_estimators=150, score=0.886, total=  16.7s
# [CV] max_features=0.75, min_samples_split=2, n_estimators=250 ........
# [CV]  max_features=0.75, min_samples_split=2, n_estimators=250, score=0.890, total=  26.4s
# [CV] max_features=0.75, min_samples_split=2, n_estimators=250 ........
# [CV]  max_features=0.75, min_samples_split=2, n_estimators=250, score=0.902, total=  29.3s
# [CV] max_features=0.75, min_samples_split=2, n_estimators=250 ........
# [CV]  max_features=0.75, min_samples_split=2, n_estimators=250, score=0.891, total=  24.3s
# [CV] max_features=0.75, min_samples_split=4, n_estimators=50 .........
# [CV]  max_features=0.75, min_samples_split=4, n_estimators=50, score=0.887, total=   4.9s
# [CV] max_features=0.75, min_samples_split=4, n_estimators=50 .........
# [CV]  max_features=0.75, min_samples_split=4, n_estimators=50, score=0.897, total=   4.6s
# [CV] max_features=0.75, min_samples_split=4, n_estimators=50 .........
# [CV]  max_features=0.75, min_samples_split=4, n_estimators=50, score=0.886, total=   4.9s
# [CV] max_features=0.75, min_samples_split=4, n_estimators=150 ........
# [CV]  max_features=0.75, min_samples_split=4, n_estimators=150, score=0.887, total=  14.6s
# [CV] max_features=0.75, min_samples_split=4, n_estimators=150 ........
# [CV]  max_features=0.75, min_samples_split=4, n_estimators=150, score=0.903, total=  14.4s
# [CV] max_features=0.75, min_samples_split=4, n_estimators=150 ........
# [CV]  max_features=0.75, min_samples_split=4, n_estimators=150, score=0.887, total=  14.4s
# [CV] max_features=0.75, min_samples_split=4, n_estimators=250 ........
# [CV]  max_features=0.75, min_samples_split=4, n_estimators=250, score=0.890, total=  29.2s
# [CV] max_features=0.75, min_samples_split=4, n_estimators=250 ........
# [CV]  max_features=0.75, min_samples_split=4, n_estimators=250, score=0.896, total=  27.9s
# [CV] max_features=0.75, min_samples_split=4, n_estimators=250 ........
# [CV]  max_features=0.75, min_samples_split=4, n_estimators=250, score=0.890, total=  25.2s
# [CV] max_features=0.75, min_samples_split=6, n_estimators=50 .........
# [CV]  max_features=0.75, min_samples_split=6, n_estimators=50, score=0.890, total=   6.5s
# [CV] max_features=0.75, min_samples_split=6, n_estimators=50 .........
# [CV]  max_features=0.75, min_samples_split=6, n_estimators=50, score=0.896, total=   6.7s
# [CV] max_features=0.75, min_samples_split=6, n_estimators=50 .........
# [CV]  max_features=0.75, min_samples_split=6, n_estimators=50, score=0.890, total=   7.1s
# [CV] max_features=0.75, min_samples_split=6, n_estimators=150 ........
# [CV]  max_features=0.75, min_samples_split=6, n_estimators=150, score=0.890, total=  18.9s
# [CV] max_features=0.75, min_samples_split=6, n_estimators=150 ........
# [CV]  max_features=0.75, min_samples_split=6, n_estimators=150, score=0.898, total=  17.0s
# [CV] max_features=0.75, min_samples_split=6, n_estimators=150 ........
# [CV]  max_features=0.75, min_samples_split=6, n_estimators=150, score=0.890, total=  16.7s
# [CV] max_features=0.75, min_samples_split=6, n_estimators=250 ........
# [CV]  max_features=0.75, min_samples_split=6, n_estimators=250, score=0.893, total=  31.1s
# [CV] max_features=0.75, min_samples_split=6, n_estimators=250 ........
# [CV]  max_features=0.75, min_samples_split=6, n_estimators=250, score=0.900, total=  28.7s
# [CV] max_features=0.75, min_samples_split=6, n_estimators=250 ........
# [CV]  max_features=0.75, min_samples_split=6, n_estimators=250, score=0.891, total=  29.0s
# [CV] max_features=1.0, min_samples_split=2, n_estimators=50 ..........
# [CV]  max_features=1.0, min_samples_split=2, n_estimators=50, score=0.890, total=   9.2s
# [CV] max_features=1.0, min_samples_split=2, n_estimators=50 ..........
# [CV]  max_features=1.0, min_samples_split=2, n_estimators=50, score=0.888, total=   6.6s
# [CV] max_features=1.0, min_samples_split=2, n_estimators=50 ..........
# [CV]  max_features=1.0, min_samples_split=2, n_estimators=50, score=0.880, total=   8.5s
# [CV] max_features=1.0, min_samples_split=2, n_estimators=150 .........
# [CV]  max_features=1.0, min_samples_split=2, n_estimators=150, score=0.895, total=  22.6s
# [CV] max_features=1.0, min_samples_split=2, n_estimators=150 .........
# [CV]  max_features=1.0, min_samples_split=2, n_estimators=150, score=0.892, total=  18.9s
# [CV] max_features=1.0, min_samples_split=2, n_estimators=150 .........
# [CV]  max_features=1.0, min_samples_split=2, n_estimators=150, score=0.890, total=  24.0s
# [CV] max_features=1.0, min_samples_split=2, n_estimators=250 .........
# [CV]  max_features=1.0, min_samples_split=2, n_estimators=250, score=0.895, total=  33.7s
# [CV] max_features=1.0, min_samples_split=2, n_estimators=250 .........
# [CV]  max_features=1.0, min_samples_split=2, n_estimators=250, score=0.898, total=  34.8s
# [CV] max_features=1.0, min_samples_split=2, n_estimators=250 .........
# [CV]  max_features=1.0, min_samples_split=2, n_estimators=250, score=0.891, total=  35.7s
# [CV] max_features=1.0, min_samples_split=4, n_estimators=50 ..........
# [CV]  max_features=1.0, min_samples_split=4, n_estimators=50, score=0.892, total=   7.0s
# [CV] max_features=1.0, min_samples_split=4, n_estimators=50 ..........
# [CV]  max_features=1.0, min_samples_split=4, n_estimators=50, score=0.895, total=   8.8s
# [CV] max_features=1.0, min_samples_split=4, n_estimators=50 ..........
# [CV]  max_features=1.0, min_samples_split=4, n_estimators=50, score=0.890, total=   5.9s
# [CV] max_features=1.0, min_samples_split=4, n_estimators=150 .........
# [CV]  max_features=1.0, min_samples_split=4, n_estimators=150, score=0.886, total=  21.0s
# [CV] max_features=1.0, min_samples_split=4, n_estimators=150 .........
# [CV]  max_features=1.0, min_samples_split=4, n_estimators=150, score=0.893, total=  21.5s
# [CV] max_features=1.0, min_samples_split=4, n_estimators=150 .........
# [CV]  max_features=1.0, min_samples_split=4, n_estimators=150, score=0.892, total=  23.8s
# [CV] max_features=1.0, min_samples_split=4, n_estimators=250 .........
# [CV]  max_features=1.0, min_samples_split=4, n_estimators=250, score=0.891, total=  43.2s
# [CV] max_features=1.0, min_samples_split=4, n_estimators=250 .........
# [CV]  max_features=1.0, min_samples_split=4, n_estimators=250, score=0.900, total=  37.0s
# [CV] max_features=1.0, min_samples_split=4, n_estimators=250 .........
# [CV]  max_features=1.0, min_samples_split=4, n_estimators=250, score=0.892, total=  36.4s
# [CV] max_features=1.0, min_samples_split=6, n_estimators=50 ..........
# [CV]  max_features=1.0, min_samples_split=6, n_estimators=50, score=0.892, total=   7.6s
# [CV] max_features=1.0, min_samples_split=6, n_estimators=50 ..........
# [CV]  max_features=1.0, min_samples_split=6, n_estimators=50, score=0.895, total=   5.9s
# [CV] max_features=1.0, min_samples_split=6, n_estimators=50 ..........
# [CV]  max_features=1.0, min_samples_split=6, n_estimators=50, score=0.890, total=   9.1s
# [CV] max_features=1.0, min_samples_split=6, n_estimators=150 .........
# [CV]  max_features=1.0, min_samples_split=6, n_estimators=150, score=0.890, total=  20.5s
# [CV] max_features=1.0, min_samples_split=6, n_estimators=150 .........
# [CV]  max_features=1.0, min_samples_split=6, n_estimators=150, score=0.894, total=  21.1s
# [CV] max_features=1.0, min_samples_split=6, n_estimators=150 .........
# [CV]  max_features=1.0, min_samples_split=6, n_estimators=150, score=0.897, total=  20.6s
# [CV] max_features=1.0, min_samples_split=6, n_estimators=250 .........
# [CV]  max_features=1.0, min_samples_split=6, n_estimators=250, score=0.890, total=  35.2s
# [CV] max_features=1.0, min_samples_split=6, n_estimators=250 .........
# [CV]  max_features=1.0, min_samples_split=6, n_estimators=250, score=0.896, total=  35.4s
# [CV] max_features=1.0, min_samples_split=6, n_estimators=250 .........
# [CV]  max_features=1.0, min_samples_split=6, n_estimators=250, score=0.889, total=  35.9s
# [Parallel(n_jobs=1)]: Done 135 out of 135 | elapsed: 25.7min finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=200, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'max_features': ['sqrt', 0.25, 0.5, 0.75, 1.0],
#                          'min_samples_split': [2, 4, 6],
#                          'n_estimators': [50, 150, 250]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'max_features': 0.25, 'min_samples_split': 4, 'n_estimators': 150}
# 0.8958611481975968

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash

import joblib
filename = 'mary_bellavia.sav'
joblib.dump(model1, filename)
# Out:
# ['mary_bellavia.sav']
